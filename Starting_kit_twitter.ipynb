# %% [markdown]
# <a href="https://colab.research.google.com/github/alexZajac/airlines_performance/blob/master/Starting_kit_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LSTM starting kit with sentiment analysis

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf
pd.options.mode.chained_assignment = None  # default='warn'
# Out:
# time: 3.19 ms (started: 2021-01-11 11:15:18 +00:00)

# %%
# !gdown "https://drive.google.com/uc?id=1s8NHRN_wAEhCCQXJw9hdvweiUARi0b_t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s8NHRN_wAEhCCQXJw9hdvweiUARi0b_t
# To: /content/tweets_NLP_dataset_clean.csv
# 27.8MB [00:00, 168MB/s]
# time: 1.64 s (started: 2021-01-11 11:15:18 +00:00)

# %%
# !gdown "https://drive.google.com/uc?id=1ADe4UbTRDdiJHrW-Og6E5UhTtdMvBnnL"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ADe4UbTRDdiJHrW-Og6E5UhTtdMvBnnL
# To: /content/featured_dataset_final_2013_2019_10_01.csv
# 100% 1.72M/1.72M [00:00<00:00, 55.0MB/s]
# time: 1.23 s (started: 2021-01-11 11:15:20 +00:00)

# %%
# !pip install ipython-autotime
# Out:
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.6/dist-packages (0.3.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from ipython-autotime) (5.5.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (0.8.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (4.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (51.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (1.0.18)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython->ipython-autotime) (0.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (0.2.5)
# time: 2.43 s (started: 2021-01-11 11:15:21 +00:00)

# %%
# %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 2.42 ms (started: 2021-01-11 11:15:23 +00:00)

# %%
CB91_Blue = '#2CBDFE'
CB91_Green = '#47DBCD'
CB91_Pink = '#F3A0F2'
CB91_Purple = '#9D2EC5'
CB91_Violet = '#661D98'
CB91_Amber = '#F5B14C'
color_list = [CB91_Blue, CB91_Pink, CB91_Green, CB91_Amber,
              CB91_Purple, CB91_Violet]
params = {"ytick.color" : "w",
          "xtick.color" : "w",
          'axes.labelsize' : 15,
          "axes.labelcolor" : "w",
          "axes.edgecolor" : "w",
          "axes.titlecolor": "w", 
          'figure.figsize': [20, 8], 
          'axes.prop_cycle': plt.cycler(color=color_list), 
          'figure.dpi' : 75, 
          'legend.fontsize': 10,
          'font.size': 15 
          }
plt.rcParams.update(params)
# Out:
# time: 8.53 ms (started: 2021-01-11 11:15:23 +00:00)

# %%
df_tweets_nlp = pd.read_csv("tweets_NLP_dataset_clean.csv", index_col=0)
df_tweets_nlp['DATE'] = pd.to_datetime(df_tweets_nlp['DATE'])
df_tweets_nlp = df_tweets_nlp.groupby(['UNIQUE_CARRIER_NAME','DATE'])['NEGATIVE','NEUTRAL','POSITIVE'].mean().reset_index(drop=False)
df_featured = pd.read_csv("featured_dataset_final_2013_2019_10_01.csv", index_col=0)
df_featured['DATE'] = pd.to_datetime(df_featured['DATE'])
load_tweet = df_featured.merge(df_tweets_nlp, left_on=['DATE','UNIQUE_CARRIER_NAME'], right_on = ['DATE','UNIQUE_CARRIER_NAME'])
load_tweet.set_index('DATE', inplace=True)
a = load_tweet['LOAD_FACTOR']
del load_tweet['LOAD_FACTOR']
load_tweet['LOAD_FACTOR'] = a
load_tweet.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                     UNIQUE_CARRIER_NAME  194  ...  POSITIVE  LOAD_FACTOR
# DATE                                          ...
# 2013-01-01  Air Wisconsin Airlines Corp  0.0  ...  0.219875     0.694164
# 2013-01-01         Alaska Airlines Inc.  0.0  ...  0.145762     0.829975
# 2013-01-01                Allegiant Air  0.0  ...  0.211078     0.868898
# 2013-01-01       American Airlines Inc.  0.0  ...  0.265715     0.801683
# 2013-01-01         Delta Air Lines Inc.  0.0  ...  0.489807     0.804674
#
# [5 rows x 132 columns]
# time: 713 ms (started: 2021-01-11 11:15:23 +00:00)

# %%
def label_encoding(data):
  le = LabelEncoder()
  for column_name in data.columns:
      if data[column_name].dtype == object:
          data[column_name] = le.fit_transform(data[column_name])
      else:
          pass
  return data
# Out:
# time: 3.79 ms (started: 2021-01-11 11:15:24 +00:00)

# %%
win_length = 2
batch_size = 2
num_features = 131
# Out:
# time: 1.41 ms (started: 2021-01-11 11:15:24 +00:00)

# %%
model2 = tf.keras.Sequential()
model2.add(tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(win_length, num_features)))
model2.add(tf.keras.layers.LSTM(128, return_sequences=True))
model2.add(tf.keras.layers.LSTM(256, return_sequences=True))
model2.add(tf.keras.layers.LSTM(128, return_sequences=True))
model2.add(tf.keras.layers.LSTM(64, return_sequences=True))
model2.add(tf.keras.layers.LSTM(num_features, return_sequences=False)) 
model2.add(tf.keras.layers.Dense(1))

model2.compile(loss=tf.losses.MeanAbsoluteError(), optimizer=tf.optimizers.Adam(), metrics=[tf.metrics.MeanAbsoluteError()])
# Out:
# time: 1.55 s (started: 2021-01-11 11:15:24 +00:00)

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 2, 64)             50176
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 2, 128)            98816
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 2, 256)            394240
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 2, 128)            197120
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 2, 64)             49408
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 131)               102704
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 132
# =================================================================
# Total params: 892,596
# Trainable params: 892,596
# Non-trainable params: 0
# _________________________________________________________________
# time: 8.24 ms (started: 2021-01-11 11:15:26 +00:00)

# %%
def LSTM_forecast(dataframe_collection, win_length, batch_size, num_features, model_LSTM):
  predictions = {}
  for dataframe in dataframe_collection:
    print('Predicting the carrier ' + dataframe + '....')
    df = dataframe_collection[dataframe].copy()
    df = label_encoding(df)
    df.pop('UNIQUE_CARRIER_NAME')
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(df)
    features = data_scaled
    target = data_scaled[:, -1]
    x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state = 12, shuffle = False)
    train_generator = TimeseriesGenerator(x_train, y_train, length=win_length, sampling_rate=1, batch_size=batch_size)
    test_generator = TimeseriesGenerator(x_test, y_test, length=win_length, sampling_rate=1, batch_size=batch_size)
    model_LSTM.fit(train_generator, epochs = 50 , validation_data=test_generator, shuffle=False, verbose = 0)
    predictions_tmp = model_LSTM.predict(test_generator)
    df_pred = pd.concat([pd.DataFrame(x_test[:,:-1][win_length:]), pd.DataFrame(predictions_tmp)], axis=1)
    df_pred.columns = range(len(df_pred.columns))
    rev_trans = scaler.inverse_transform(df_pred)
    df_final = df[predictions_tmp.shape[0]*-1:]
    df_final['PRED'] = rev_trans[:, -1]
    tmp = df_final[['LOAD_FACTOR', 'PRED']]
    predictions[dataframe] = tmp
    print('METRIC TEMPORAIRE :' + str(mean_absolute_error(df_final['PRED'], df_final['LOAD_FACTOR'])))
    plt.plot(df_final.index, df_final['LOAD_FACTOR'], label='True Load Factor')
    plt.plot(df_final.index, df_final['PRED'], label='Predicted Load Factor')
    plt.title('Predictions for the carrier : ' + dataframe)
    plt.show()
  return predictions
# Out:
# time: 32.1 ms (started: 2021-01-11 11:15:26 +00:00)

# %%
carriers = np.unique(load_tweet['UNIQUE_CARRIER_NAME'])
dataframe_collection = {} 
for carrier in carriers:
  if carrier != 'US Airways Inc.':
    dataframe_collection[carrier] = load_tweet[load_tweet['UNIQUE_CARRIER_NAME'] == carrier]
dataframe_collection['SkyWest Airlines Inc.'].head()
# Out:
#               UNIQUE_CARRIER_NAME  194   26  ...   NEUTRAL  POSITIVE  LOAD_FACTOR
# DATE                                         ...
# 2013-01-01  SkyWest Airlines Inc.  0.0  0.0  ...  0.584692  0.294082     0.784116
# 2013-02-01  SkyWest Airlines Inc.  0.0  0.0  ...  0.742766  0.173678     0.805831
# 2013-03-01  SkyWest Airlines Inc.  0.0  0.0  ...  0.678459  0.227472     0.826178
# 2013-04-01  SkyWest Airlines Inc.  0.0  0.0  ...  0.693496  0.192978     0.818458
# 2013-05-01  SkyWest Airlines Inc.  0.0  0.0  ...  0.655444  0.318188     0.836107
#
# [5 rows x 132 columns]
# time: 156 ms (started: 2021-01-11 11:15:26 +00:00)

# %%
predictions = LSTM_forecast(dataframe_collection, win_length, batch_size, num_features, model2)
# Out:
# Predicting the carrier Air Wisconsin Airlines Corp....
# METRIC TEMPORAIRE :0.037249306268130195
# Predicting the carrier Alaska Airlines Inc.....
# METRIC TEMPORAIRE :0.03307782123157926
# Predicting the carrier Allegiant Air....
# METRIC TEMPORAIRE :0.019742267766423446
# Predicting the carrier American Airlines Inc.....
# METRIC TEMPORAIRE :0.03696488144309431
# Predicting the carrier Delta Air Lines Inc.....
# METRIC TEMPORAIRE :0.02012454548602681
# Predicting the carrier Endeavor Air Inc.....
# METRIC TEMPORAIRE :0.03637220390132683
# Predicting the carrier Envoy Air....
# METRIC TEMPORAIRE :0.023973327769171333
# Predicting the carrier ExpressJet Airlines LLC....
# METRIC TEMPORAIRE :0.02868203696410777
# Predicting the carrier Frontier Airlines Inc.....
# METRIC TEMPORAIRE :0.030434428825251564
# Predicting the carrier GoJet Airlines LLC d/b/a United Express....
# METRIC TEMPORAIRE :0.026236524717379302
# Predicting the carrier Grant Aviation....
# METRIC TEMPORAIRE :0.04272900160971152
# Predicting the carrier JetBlue Airways....
# METRIC TEMPORAIRE :0.025729802428159455
# Predicting the carrier Mesa Airlines Inc.....
# METRIC TEMPORAIRE :0.021474004191010847
# Predicting the carrier PSA Airlines Inc.....
# METRIC TEMPORAIRE :0.030142458328042434
# Predicting the carrier Republic Airline....
# METRIC TEMPORAIRE :0.03439972043850928
# Predicting the carrier Shuttle America Corp.....
# METRIC TEMPORAIRE :0.04541563432504684
# Predicting the carrier SkyWest Airlines Inc.....
# METRIC TEMPORAIRE :0.031089838201639377
# Predicting the carrier Southwest Airlines Co.....
# METRIC TEMPORAIRE :0.02208609259618641
# Predicting the carrier Spirit Air Lines....
# METRIC TEMPORAIRE :0.03585107220378734
# Predicting the carrier Sun Country Airlines d/b/a MN Airlines....
# METRIC TEMPORAIRE :0.052046108888772924
# Predicting the carrier United Air Lines Inc.....
# METRIC TEMPORAIRE :0.030321839186396096
# time: 10min 34s (started: 2021-01-11 11:15:26 +00:00)

# %%
final_pred = pd.concat(predictions)
final_pred.head()
# Out:
#                                         LOAD_FACTOR      PRED
#                             DATE
# Air Wisconsin Airlines Corp 2018-01-01     0.718352  0.765625
#                             2018-02-01     0.742246  0.760074
#                             2018-03-01     0.795028  0.760184
#                             2018-04-01     0.798935  0.736033
#                             2018-05-01     0.811830  0.797678
# time: 29 ms (started: 2021-01-11 11:26:00 +00:00)

# %%
final_pred.reset_index(level=0, inplace=True)
final_pred.rename(columns={'level_0': 'UNIQUE_CARRIER_NAME'}, inplace = True)
final_pred.reset_index(level=0, inplace=True)
final_pred.rename(columns={'level_0': 'DATE'}, inplace = True)
# Out:
# time: 7.12 ms (started: 2021-01-11 11:26:00 +00:00)

# %%
final_pred.head()
# Out:
#         DATE          UNIQUE_CARRIER_NAME  LOAD_FACTOR      PRED
# 0 2018-01-01  Air Wisconsin Airlines Corp     0.718352  0.765625
# 1 2018-02-01  Air Wisconsin Airlines Corp     0.742246  0.760074
# 2 2018-03-01  Air Wisconsin Airlines Corp     0.795028  0.760184
# 3 2018-04-01  Air Wisconsin Airlines Corp     0.798935  0.736033
# 4 2018-05-01  Air Wisconsin Airlines Corp     0.811830  0.797678
# time: 18.7 ms (started: 2021-01-11 11:26:00 +00:00)

# %%
mean_absolute_error(final_pred['LOAD_FACTOR'], final_pred['PRED'])
# Out:
# 0.031316182928841994
# time: 4.33 ms (started: 2021-01-11 11:26:00 +00:00)

# %%
max(df_tweets_nlp["DATE"])
# Out:
# Timestamp('2019-12-01 00:00:00')
# time: 8.73 ms (started: 2021-01-11 11:26:00 +00:00)
